# %%
# !pip install geopandas
# !pip install earthpy
# !pip install descartes # required for plotting polygons in geopandas
# Out:
# ...
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the &#39;/usr/local/bin/python3 -m pip install --upgrade pip&#39; command.
# ...
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the &#39;/usr/local/bin/python3 -m pip install --upgrade pip&#39; command.
# ...
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the &#39;/usr/local/bin/python3 -m pip install --upgrade pip&#39; command.

# %%
# import necessary packages
import os
import matplotlib.pyplot as plt
import geopandas as gpd
import earthpy as et

# %%
# move to the "COVID-19-Vaccine-Allocation" directory
if os.path.basename(os.path.dirname(os.getcwd())) == "code":
    os.chdir(os.path.join(os.getcwd(), os.pardir))

# do work with the shapefile
df = gpd.read_file("shape/la_shape.shp")
# print(df.head()) # view the data attribute table 
# df.total_bounds # view the spatial extent
# df.crs # view the Coordinate Reference System (CRS) 
# df.plot()
# Out:
# &lt;AxesSubplot:&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
