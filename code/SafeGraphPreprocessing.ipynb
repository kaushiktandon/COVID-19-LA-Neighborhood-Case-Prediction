# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
parts = ['C:\\Users\\kaush\\Downloads\\patterns-part1.csv', 'C:\\Users\\kaush\\Downloads\\patterns-part2.csv', 'C:\\Users\\kaush\\Downloads\\patterns-part3.csv', 'C:\\Users\\kaush\\Downloads\\patterns-part4.csv']
new_path = 'C:\\Users\\kaush\\Downloads\\october_safegraph.csv'
monthly_patterns_raw = pd.concat(map(pd.read_csv, parts)).reset_index(drop=True)
monthly_patterns_raw.head()
# Out:
#               placekey                   safegraph_place_id  \
# 0  225-222@8dh-cwb-nt9  sg:000cdb71c9da43888e26fab3cfc79b32
# 1  zzy-222@8dz-pnb-6rk  sg:000ebbb72c554ad590c31a20b2db4490
# 2  zzw-222@63g-r5v-89z  sg:00163ba0286241faa3be5209b24aa63f
# 3  225-224@5yv-j9g-snq  sg:00230bfc4a9c4f3aa1f60166fe97ad52
# 4  225-222@8gd-pwy-zs5  sg:002671edac5344a1aac446b7a42a15c7
#
#                              location_name          street_address  \
# 0                      Keys Swimming Pools  1472 74th Street Ocean
# 1                     Tommy's Full Service            210 Craig Rd
# 2  Bon Secours Pediatric Dental Associates     1850 Pocahontas Trl
# 3                               Rapid Cash      4241 S Nellis Blvd
# 4                         Miles Dale A DMD      316 Stephenson Ave
#
#          city region  postal_code safegraph_brand_ids brands  \
# 0    Marathon     FL        33050                 NaN    NaN
# 1  Broken Bow     OK        74728                 NaN    NaN
# ...

# %%
monthly_patterns_raw = monthly_patterns_raw[monthly_patterns_raw['region'] == 'CA']
monthly_patterns_raw['county_tract'] = (monthly_patterns_raw['poi_cbg'] / 1000000).astype(int)
monthly_patterns_raw = monthly_patterns_raw[monthly_patterns_raw['county_tract'] == 60371]

# %%
monthly_patterns_raw.to_csv(new_path, encoding='utf-8', index=False)
